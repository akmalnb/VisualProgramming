# %%
print ("hello")
# Out:
# hello

# %%
65*65
# Out:
# 4225

# %%
x=8
y=78
z= x + y

# %%
print (z)
# Out:
# 86

# %%
from PIL import Image
from skimage.io import imread, imsave, imshow, show
import matplotlib.pylab as plt

# %%
im = Image.open("./iRzr7lw.jpg")
im.show()

# %%
print(im.width, im.height, im.mode, im.format)
# Out:
# 5888 3312 RGB JPEG

# %%
import imageio
im2 = imageio.imread("./iRzr7lw.jpg")
plt.imshow(im2)

# %%
 import matplotlib.pylab as pylab

# %%
imu = im.resize((im.width*2, im.height*2))
plt.imshow(imu)

# %%
mu = im.resize((im.width//2,  im.height//2))
plt.imshow(imu)

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(im);
ax[1].imshow(imu);

# %%
import numpy as np
import cv2

# %%
im4 = cv2.imread("./iRzr7lw.jpg")
cv2.imshow("image",im4)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im4 = cv2.imread("./iRzr7lw.jpg",0)
cv2.imshow("image",im4)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(10,10))
#plt.axis('off')
print(im3.shape)
plt.imshow(im3)

# %%
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract
from skimage.io import imread, imshow, show
from skimage.transform import SimilarityTransform, warp, swirl
from scipy.ndimage import affine_transform
import matplotlib.image as mpimg
import matplotlib.pylab as plt

# %%
im1 = mpimg.imread("flower1.jpg") / 255
im2 = mpimg.imread("flower2.jpg") / 255
i = 1
plt.figure(figsize=(18,15))
for alpha in np.linspace(0,1,20):
    plt.subplot(4,5,i)
    plt.imshow((1-alpha)*im1 + alpha*im2)
    plt.axis('off')
    i += 1
plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-76e74a28c0c2> in <module>
#       3 i = 1
#       4 plt.figure(figsize=(18,15))
# ----> 5 for alpha in np.linspace(0,1,20):
#       6     plt.subplot(4,5,i)
#       7     plt.imshow((1-alpha)*im1 + alpha*im2)
#
# NameError: name 'np' is not defined
