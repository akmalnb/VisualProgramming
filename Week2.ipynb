# %%
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract
from skimage.io import imread, imshow, show
from skimage.transform import SimilarityTransform, warp, swirl
from scipy.ndimage import affine_transform
import matplotlib.image as mpimg
import matplotlib.pylab as plt
import numpy as np

# %%
im1 = mpimg.imread("./flower1.jpg") / 255
im2 = mpimg.imread("./flower2.jpg") / 255
i = 1
plt.figure(figsize=(18,15))
for alpha in np.linspace(0,1,20):
    plt.subplot(4,5,i)
    plt.imshow((1-alpha)*im1 + alpha*im2)
    plt.axis('off')
    i += 1
plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()

# %%
im3 = Image.open("flower.jpg")
print (im3.width, im3.height, im3.mode, im3.format)
# Out:
# 360 174 RGB JPEG

# %%
im3_crop = im3.crop((175,75,320,200))
im3_crop.show()
plt.imshow(im3_crop)

# %%
im3_negative= im3.point(lambda x:255-x)
im3_negative.show()
plt.imshow(im3_negative)

# %%
im_grayscale = im3.convert('L')
im_grayscale.show()
plt.imshow(im_grayscale)

# %%
im_grayscale.point(lambda x: 255*np.log(1+x/255)).show()

# %%
im_grayscale.point(lambda x: 255*(x/255)**0.6).show()

# %%
#reflect about the vertical axis
im3_rotate1 = im3.transpose(Image.FLIP_LEFT_RIGHT).show()
#reflect about horizontal axis
im3_rotate2 = im3. transpose(Image.FLIP_TOP_BOTTOM).show()

# %%
im3_rotate45= im3.rotate(45).show()

# %%
#choose 5000 random locations inside image
imcopy = im3.copy() # keep the original image, create a copy\
n = 5000
x, y = np.random.randint(0, imcopy.width, n), np.random.randint(0, imcopy.height,n)
for (x,y) in zip (x,y):
    imcopy.putpixel((x, y), ((0,0,0) if np.random.rand() < 0.5 else (255,255,255)))
    imcopy.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-9b0231fee935> in <module>
#       5 for (x,y) in zip (x,y):
#       6     imcopy.putpixel((x, y), ((0,0,0) if np.random.rand() < 0.5 else (255,255,255)))
# ----> 7     imcopy.show()
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in show(self, title, command)
#    2203             )
#    2204
# -> 2205         _show(self, title=title, command=command)
#    2206
#    2207     def split(self):
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _show(image, **options)
#    3165 def _show(image, **options):
#    3166     options["_internal_pillow"] = True
# -> 3167     _showxv(image, **options)
#    3168
#    3169
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _showxv(image, title, **options)
#    3179             DeprecationWarning,
#    3180         )
# -> 3181     ImageShow.show(image, title, **options)
#    3182
#    3183
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show(image, title, **options)
#      54     """
#      55     for viewer in _viewers:
# ---> 56         if viewer.show(image, title=title, **options):
#      57             return 1
#      58     return 0
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show(self, image, **options)
#      79                 image = image.convert(base)
#      80
# ---> 81         return self.show_image(image, **options)
#      82
#      83     # hook methods
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show_image(self, image, **options)
#     105     def show_image(self, image, **options):
#     106         """Display the given image."""
# --> 107         return self.show_file(self.save_image(image), **options)
#     108
#     109     def show_file(self, file, **options):
#
# ~\anaconda3\lib\site-packages\PIL\ImageShow.py in show_file(self, file, **options)
#     109     def show_file(self, file, **options):
#     110         """Display the given file."""
# --> 111         os.system(self.get_command(file, **options))
#     112         return 1
#     113
#
# KeyboardInterrupt:

# %%
im4 = Image.open('flower3.jpg')
draw = ImageDraw.Draw(im4)
draw.ellipse((125, 125, 200, 250), fill= (255,255,255,128))
del draw
im4.show()

# %%
draw = ImageDraw.Draw(im4)
font = ImageFont.truetype("arial.ttf", 23) # use a truetype font
draw.text((10, 5), "Welcome to image processing", font=font)
del draw
im4.show()

# %%
im5 = Image.open("flower4.jpg")
im6 = Image.open("flower5.jpg").convert('RGB').resize((im5.width,im5.height))
multiply(im5, im6).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-15ed39128633> in <module>
#       1 im5 = Image.open("flower4.jpg")
#       2 im6 = Image.open("flower5.jpg").convert('RGB').resize((im5.width,im5.height))
# ----> 3 multiply(im5, im6).show()
#
# NameError: name 'multiply' is not defined
